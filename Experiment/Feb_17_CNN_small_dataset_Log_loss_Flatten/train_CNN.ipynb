# %%
import numpy as np
import keras
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, ZeroPadding2D
from keras.layers.normalization import BatchNormalization
from PIL import Image
import random
import math
import matplotlib.pyplot as plt
import dendropy
import csv
from dendropy.calculate import treecompare
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Loading Data

# %%
whole_data = np.load('../../Data_Preprocessing/output/500_Dataset/training_data.npy')
whole_labels_cub = np.load('../../Data_Preprocessing/output/500_Dataset/training_dists_cub.npy')
whole_labels_flatten = np.load('../../Data_Preprocessing/output/500_Dataset/training_dists_flatten.npy')

# %%
BRANCH_NUM = 100
SEQUENCE_LEN = 1000

OUTPUT_DIST_NUM = int((BRANCH_NUM - 1) * BRANCH_NUM / 2)

# %%
print(whole_data.shape)
print(whole_labels_cub.shape)
print(whole_labels_flatten.shape)
# Out:
# (500, 100, 1000, 1)
# (500, 100, 100, 1)
# (500, 4950)

# %% [markdown]
# ### Plot before shuffle

# %%
whole_data_before_shuffle = whole_data.reshape((whole_data.shape[0]*100, 1000))
plt.imshow(whole_data_before_shuffle, cmap='hot', interpolation='nearest', aspect='auto')
plt.show()

# %% [markdown]
# ## Shuffle each input sampe (dim: 100 * 1000)

# %% [markdown]
# #### Use the same index for all input sample

# %%
shuffle_indices_100 = random.sample(range(0, 100), 100)
shuffle_indices_1000 = random.sample(range(0, 1000), 1000)

# %%
for i in range(whole_data.shape[0]):
    tmp = whole_data[i][shuffle_indices_100]
    tmp = tmp[:, shuffle_indices_1000]
    whole_data[i] = tmp

# %% [markdown]
# ### Plot after shuffle

# %%
whole_data_after_shuffle = whole_data.reshape((whole_data.shape[0]*100, 1000))
plt.imshow(whole_data_after_shuffle, cmap='hot', interpolation='nearest', aspect='auto')
plt.show()

# %% [markdown]
# # Training Testing Dataset Partition

# %%
samples_count = whole_data.shape[0]

train_size = math.floor(0.85*whole_data.shape[0])

shuffle_indices = random.sample(range(0, samples_count), samples_count)

print(len(np.unique(shuffle_indices)))
# Out:
# 500

# %%
indices_train = shuffle_indices[0:train_size]
indices_test = shuffle_indices[train_size:samples_count]

# %%
print("######## Training Data ########")
X_train = whole_data[indices_train,:]
Y_train_cub = whole_labels_cub[indices_train]
Y_train_flatten = whole_labels_flatten[indices_train]

print("######## Validation Data ########")
X_test = whole_data[indices_test,:]
Y_test_cub = whole_labels_cub[indices_test]
Y_test_flatten = whole_labels_flatten[indices_test]

print('X_train.shape : ', X_train.shape)
print('X_test.shape : ', Y_train_cub.shape)

print('Y_train_cub.shape : ', Y_train_cub.shape)
print('Y_test_cub.shape : ', Y_test_cub.shape)
print('Y_train_flatten.shape : ', Y_train_flatten.shape)
print('Y_test_flatten.shape : ', Y_test_flatten.shape)# Training Testing Dataset Partition
# Out:
# ######## Training Data ########
# ######## Validation Data ########
# X_train.shape :  (425, 100, 1000, 1)
# X_test.shape :  (425, 100, 100, 1)
# Y_train_cub.shape :  (425, 100, 100, 1)
# Y_test_cub.shape :  (75, 100, 100, 1)
# Y_train_flatten.shape :  (425, 4950)
# Y_test_flatten.shape :  (75, 4950)

# %% [markdown]
# ### Plot for shuffled X_train (samples)

# %%
X_train_shuffle = X_train.reshape((X_train.shape[0]*100, 1000))

# %%
plt.imshow(X_train_shuffle, cmap='hot', interpolation='nearest', aspect='auto')
plt.show()

# %% [markdown]
# ### Plot for shuffled X_test (samples)

# %%
X_test_shuffle = X_test.reshape((X_test.shape[0]*100, 1000))

# %%
plt.imshow(X_test_shuffle, cmap='hot', interpolation='nearest', aspect='auto')
plt.show()

# %%
np.save('./output/X_train.npy', X_train)
np.save('./output/Y_train_cub.npy', Y_train_cub)
np.save('./output/Y_train_flatten.npy', Y_train_flatten)

np.save('./output/X_test.npy', X_test)
np.save('./output/Y_test_cub.npy', Y_test_cub)
np.save('./output/Y_test_flatten.npy', Y_test_flatten)

# %% [markdown]
# ### Load Data

# %%
# X_train = np.load('./output/X_train.npy')
# Y_train_cub = np.load('./output/Y_train_cub.npy')
# Y_train_flatten = np.load('./output/Y_train_flatten.npy')

# X_test = np.load('./output/X_test.npy')
# Y_test_cub = np.load('./output/Y_test_cub.npy')
# Y_test_flatten = np.load('./output/Y_test_flatten.npy')

# %%
# model = Sequential()

# # Layer 1
# model.add(Conv2D(64, input_shape=X_train.shape[1:], kernel_size=(3,3), strides=(1,1), padding='same'))
# #model.add(Conv2D(48, input_shape=(400,11,1), kernel_size=(2,2), strides=(1,1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# # model.add(MaxPooling2D(pool_size=(1, 2)))

# # Layer 2
# model.add(Conv2D(32, (3,3), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# # model.add(MaxPooling2D(pool_size=(1, 2)))

# # Layer 3
# model.add(Conv2D(16, (3,3), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# # model.add(MaxPooling2D(pool_size=(1, 2)))

# # Layer 4
# model.add(Conv2D(1, (2, 1), padding='same'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(1, 2)))

# %%
model = Sequential()

# Layer 1
model.add(Conv2D(100, input_shape=X_train.shape[1:], kernel_size=(100,1), strides=(1,1)))
#model.add(Conv2D(48, input_shape=(400,11,1), kernel_size=(2,2), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))

# Layer 2
model.add(Conv2D(10, (1, 2)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))

# Layer 3
model.add(Conv2D(5, (1, 2)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))

# Layer 4
model.add(Conv2D(1, (1, 2)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))

# Layer 5
model.add(Flatten())
model.add(Dense(OUTPUT_DIST_NUM, activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 1, 1000, 100)      10100
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1, 1000, 100)      400
# _________________________________________________________________
# activation_1 (Activation)    (None, 1, 1000, 100)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1000, 100)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 999, 10)        2010
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 999, 10)        40
# _________________________________________________________________
# activation_2 (Activation)    (None, 1, 999, 10)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 999, 10)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 998, 5)         105
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1, 998, 5)         20
# _________________________________________________________________
# activation_3 (Activation)    (None, 1, 998, 5)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 998, 5)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 997, 1)         11
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 997, 1)         4
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 997, 1)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 997, 1)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 997)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4950)              4940100
# =================================================================
# Total params: 4,952,790
# Trainable params: 4,952,558
# Non-trainable params: 232
# _________________________________________________________________

# %%
# def log_loss:
#     if not K.is_tensor(y_pred):
#         y_pred = K.constant(y_pred)
#     y_true = K.cast(y_true, y_pred.dtype)
    
#     return K.log(K.square(y_pred - y_true), axis=-1)

# %%
# (4) Compile 
#model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
model.compile(loss='mean_squared_logarithmic_error', optimizer='adam', metrics=['accuracy'])

# %%
loss_list_epoch= []
RF_avg_distance_epoch = []
RF_list_distance_epoch = []

# %%
## This function is defined for vector -> symmetric distance matrix
def utri2mat(utri):
    n = (int(-1 + np.sqrt(1 + 8*len(utri))) // 2) + 1
    iu1 = np.triu_indices(n-1)
    iu1 = (iu1[0], iu1[1] + 1)
    ret = np.zeros((n, n))
    ret[iu1] = utri
    ret.T[iu1] = utri
    return ret

# %%
# Do first time to initial the tree!
print("******** Start fitting model ********")
history = model.fit(X_train, Y_train_flatten, validation_data=(X_test, Y_test_flatten), batch_size=50, epochs=1, verbose=1)
print(history.history['loss'])
loss_list_epoch.append(history.history['loss'][0])

print("******** Start calculating RF Distance ********")
RF_list_distance = []
for index in range(len(X_train)):
    tips_num = np.count_nonzero(np.sum(X_train[index], axis=1) != 0) 
#         print("tips_num: ", tips_num)
    array_selection_length = int((tips_num + 1) * tips_num / 2)
    Y_train_flatten_vec_sel = Y_train_flatten[index][0:array_selection_length]
    X_train_results = model.predict(X_train[index].reshape((1, 100, 1000, 1)))
    X_train_results_vec_sel = X_train_results[0][0:array_selection_length]
    original_dis_matrix = utri2mat(Y_train_flatten_vec_sel)
    new_dis_matrix = utri2mat(X_train_results_vec_sel)
    for i in range(len(new_dis_matrix)):
        new_dis_matrix[i,i] = 0
    with open('./output/CSV/original_dis_matrix'+str(index)+'.csv', mode='w') as my_csv:
        csvWriter = csv.writer(my_csv,delimiter=',')
        csvWriter.writerows(original_dis_matrix)
    with open('./output/CSV/new_dis_matrix'+str(index)+'.csv', mode='w') as my_csv:
        csvWriter = csv.writer(my_csv,delimiter=',')
        csvWriter.writerows(new_dis_matrix)
    taxon_namespace = dendropy.TaxonSet()
    pdm_origin = dendropy.PhylogeneticDistanceMatrix.from_csv(
            src=open('./output/CSV/original_dis_matrix'+str(index)+'.csv'),
            is_first_row_column_names=False,
            is_first_column_row_names=False,
            delimiter=",",
            taxon_namespace = taxon_namespace)
    pdm_new = dendropy.PhylogeneticDistanceMatrix.from_csv(
            src=open('./output/CSV/new_dis_matrix'+str(index)+'.csv'),
            is_first_row_column_names=False,
            is_first_column_row_names=False,
            delimiter=",",
            taxon_namespace = taxon_namespace)
    tree_origin = pdm_origin.nj_tree()
    tree_new = pdm_new.nj_tree()
    RF_distance = treecompare.symmetric_difference(tree_origin, tree_new)
    RF_list_distance.append(RF_distance)
RF_list_distance_epoch.append(RF_list_distance)
RF_avg_distance_epoch.append(sum(RF_list_distance) / len(RF_list_distance))
print("RF_list_distance: ", RF_list_distance)
print("RF_avg_distance_epoch: ", RF_avg_distance_epoch)
# Out:
# ******** Start fitting model ********
# Train on 425 samples, validate on 75 samples
# Epoch 1/1
# 425/425 [==============================] - 2s 4ms/step - loss: 0.0574 - accuracy: 0.0000e+00 - val_loss: 0.0808 - val_accuracy: 0.0000e+00
# [0.05740135469857384]
# ******** Start calculating RF Distance ********
# /home/howard/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py
        array_selection_length = int((tips_num + 1) * tips_num / 2)
        Y_train_flatten_vec_sel = Y_train_flatten[index][0:array_selection_length]
        X_train_results = model.predict(X_train[index].reshape((1, 100, 1000, 1)))
        X_train_results_vec_sel = X_train_results[0][0:array_selection_length]
        original_dis_matrix = utri2mat(Y_train_flatten_vec_sel)
        new_dis_matrix = utri2mat(X_train_results_vec_sel)
        for i in range(len(new_dis_matrix)):
            new_dis_matrix[i,i] = 0
        with open('./output/CSV/original_dis_matrix'+str(index)+'.csv', mode='w') as my_csv:
            csvWriter = csv.writer(my_csv,delimiter=',')
            csvWriter.writerows(original_dis_matrix)
        with open('./output/CSV/new_dis_matrix'+str(index)+'.csv', mode='w') as my_csv:
            csvWriter = csv.writer(my_csv,delimiter=',')
            csvWriter.writerows(new_dis_matrix)
        taxon_namespace = dendropy.TaxonSet()
        pdm_origin = dendropy.PhylogeneticDistanceMatrix.from_csv(
                src=open('./output/CSV/original_dis_matrix'+str(index)+'.csv'),
                is_first_row_column_names=False,
                is_first_column_row_names=False,
                delimiter=",",
                taxon_namespace = taxon_namespace)
        pdm_new = dendropy.PhylogeneticDistanceMatrix.from_csv(
                src=open('./output/CSV/new_dis_matrix'+str(index)+'.csv'),
                is_first_row_column_names=False,
                is_first_column_row_names=False,
                delimiter=",",
                taxon_namespace = taxon_namespace)
        tree_origin = pdm_origin.nj_tree()
        tree_new = pdm_new.nj_tree()
        RF_distance = treecompare.symmetric_difference(tree_origin, tree_new)
        RF_list_distance.append(RF_distance)
    RF_list_distance_epoch.append(RF_list_distance)
    RF_avg_distance_epoch.append(sum(RF_list_distance) / len(RF_list_distance))
    print("RF_list_distance: ", RF_list_distance)
    print("RF_avg_distance_epoch: ", RF_avg_distance_epoch)
# Out:
# ******** Start fitting model ********
# Train on 425 samples, validate on 75 samples
# Epoch 1/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0394 - accuracy: 0.0000e+00 - val_loss: 0.0471 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0339 - accuracy: 0.0000e+00 - val_loss: 0.0451 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0313 - accuracy: 0.0024 - val_loss: 0.0509 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 425/425 [==============================] - 5s 11ms/step - loss: 0.0279 - accuracy: 0.0094 - val_loss: 0.0472 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0247 - accuracy: 0.0165 - val_loss: 0.0516 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0233 - accuracy: 0.0212 - val_loss: 0.0478 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0210 - accuracy: 0.0212 - val_loss: 0.0530 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 425/425 [==============================] - 5s 11ms/step - loss: 0.0193 - accuracy: 0.0259 - val_loss: 0.0486 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0178 - accuracy: 0.0400 - val_loss: 0.0484 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 425/425 [==============================] - 5s 11ms/step - loss: 0.0166 - accuracy: 0.0424 - val_loss: 0.0548 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0160 - accuracy: 0.0424 - val_loss: 0.0500 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0151 - accuracy: 0.0400 - val_loss: 0.0518 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0145 - accuracy: 0.0494 - val_loss: 0.0504 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0136 - accuracy: 0.0588 - val_loss: 0.0513 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 425/425 [==============================] - 5s 11ms/step - loss: 0.0128 - accuracy: 0.0376 - val_loss: 0.0539 - val_accuracy: 0.0133
# Epoch 16/50
# 425/425 [==============================] - 5s 11ms/step - loss: 0.0130 - accuracy: 0.0682 - val_loss: 0.0517 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0125 - accuracy: 0.0753 - val_loss: 0.0545 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0119 - accuracy: 0.0871 - val_loss: 0.0551 - val_accuracy: 0.0133
# Epoch 19/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0114 - accuracy: 0.0635 - val_loss: 0.0546 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0108 - accuracy: 0.0894 - val_loss: 0.0563 - val_accuracy: 0.0133
# Epoch 21/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0107 - accuracy: 0.0706 - val_loss: 0.0549 - val_accuracy: 0.0133
# Epoch 22/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0103 - accuracy: 0.0871 - val_loss: 0.0565 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.
# RF_avg_distance_epoch:  [112.60235294117648, 101.52941176470588, 99.39764705882352, 98.94117647058823, 99.57176470588236, 98.63529411764706, 95.92, 97.04941176470588, 97.39294117647059, 97.9435294117647]
# ******** Start fitting model ********
# Train on 425 samples, validate on 75 samples
# Epoch 1/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5882 - val_loss: 0.0745 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5765 - val_loss: 0.0734 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5976 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5929 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5788 - val_loss: 0.0745 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5765 - val_loss: 0.0747 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5976 - val_loss: 0.0729 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5812 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 425/425 [==============================] - 5s 11ms/step - loss: 0.0033 - accuracy: 0.5600 - val_loss: 0.0745 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5482 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5929 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5812 - val_loss: 0.0747 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5435 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5741 - val_loss: 0.0740 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5859 - val_loss: 0.0735 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5976 - val_loss: 0.0744 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5741 - val_loss: 0.0733 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.6000 - val_loss: 0.0744 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 425/425 [==============================] - 5s 11ms/step - loss: 0.0034 - accuracy: 0.5859 - val_loss: 0.0733 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.6024 - val_loss: 0.0746 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5835 - val_loss: 0.0742 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5953 - val_loss: 0.0745 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 425/425 [==============================] - 5s 11ms/step - loss: 0.0033 - accuracy: 0.5976 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5812 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5718 - val_loss: 0.0735 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 425/425 [==============================] - 5s 11ms/step - loss: 0.0034 - accuracy: 0.5976 - val_loss: 0.0749 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5859 - val_loss: 0.0746 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5788 - val_loss: 0.0744 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5788 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5600 - val_loss: 0.0737 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.6259 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5765 - val_loss: 0.0747 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 425/425 [==============================] - 5s 13ms/step - loss: 0.0033 - accuracy: 0.6165 - val_loss: 0.0743 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 425/425 [==============================] - 5s 13ms/step - loss: 0.0033 - accuracy: 0.6047 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5765 - val_loss: 0.0747 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.6024 - val_loss: 0.0742 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5882 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.6047 - val_loss: 0.0748 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5859 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.6024 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.6282 - val_loss: 0.0745 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.6094 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.6188 - val_loss: 0.0746 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.6165 - val_loss: 0.0742 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.6118 - val_loss: 0.0750 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5788 - val_loss: 0.0749 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5812 - val_loss: 0.0763 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0034 - accuracy: 0.5647 - val_loss: 0.0749 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.5953 - val_loss: 0.0742 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 425/425 [==============================] - 5s 12ms/step - loss: 0.0033 - accuracy: 0.6188 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# [0.0033559100539423525, 0.003383005279910696, 0.003373896321007872, 0.0033806015562046978, 0.0034012779901625915, 0.0033748559468864078, 0.003346713437452255, 0.003336361017941004, 0.0033307623063378476, 0.00332927464534912, 0.003359195651650867, 0.0033604561586809507, 0.0033996163140160634, 0.003391866540426717, 0.0033611860306358293, 0.003381747479468365, 0.0033709035653566176, 0.003324921697254895, 0.0033529084653812734, 
# RF_avg_distance_epoch:  [112.60235294117648, 101.52941176470588, 99.39764705882352, 98.94117647058823, 99.57176470588236, 98.63529411764706, 95.92, 97.04941176470588, 97.39294117647059, 97.9435294117647, 95.80705882352942]

# %%
model.save('./output/CNN_model_03.h5')

# %%
train_result = model.evaluate(X_train, Y_train_flatten)
test_result = model.evaluate(X_test, Y_test_flatten)
print("Train Acc: ", train_result)
print("Test Acc: ", test_result)
# Out:
# 425/425 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# Train Acc:  [0.003561989152804017, 0.5364705920219421]
# Test Acc:  [0.074073832432429, 0.0]

# %% [markdown]
# ## Load the Model

# %%
# model = keras.models.load_model('./output/CNN_model_03.h5')

# %% [markdown]
# ## X_train plot

# %%
X_train_results = model.predict(X_train)

# %%
train_show_index = 0

# %%
plt.scatter(range(X_train_results[train_show_index].shape[0]), X_train_results[train_show_index], c='r', s = 2)
plt.scatter(range(Y_train_flatten[train_show_index].shape[0]), Y_train_flatten[train_show_index], c='g', s = 2)
plt.xlabel ('Flatten Distance Matrix Index')
plt.ylabel ('Distance Matrix Value')
# Out:
# Text(0, 0.5, 'Distance Matrix Value')

# %%
plt.scatter(X_train_results[train_show_index], Y_train_flatten[train_show_index], c='r', s = 2)
plt.xlabel ('Training Data Prediction')
plt.ylabel ('Training Data Label')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X_train_results_resh= X_train_results.reshape((1, 425*OUTPUT_DIST_NUM))
Y_train_resh = Y_train_flatten.reshape((1, 425*OUTPUT_DIST_NUM))

# %%
plt.scatter(X_train_results_resh, Y_train_resh, c='r', s = 2)
plt.xlabel ('Training Data Prediction')
plt.ylabel ('Training Data Label')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## X_test plot

# %%
X_test_results = model.predict(X_test)

# %%
test_show_index = 10

# %%
plt.scatter(range(X_test_results[test_show_index].shape[0]), X_test_results[test_show_index], c='r', s = 2)
plt.scatter(range(Y_test_flatten[test_show_index].shape[0]), Y_test_flatten[test_show_index], c='g', s = 2)
plt.xlabel ('Flatten Distance Matrix Index')
plt.ylabel ('Distance Matrix Value')
# Out:
# Text(0, 0.5, 'Distance Matrix Value')

# %%
plt.scatter(X_test_results[train_show_index], Y_test_flatten[train_show_index], c='r', s = 2)
plt.xlabel ('Validation Data Prediction')
plt.ylabel ('Validation Data Label')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X_test_results_resh= X_test_results.reshape((1, 75*OUTPUT_DIST_NUM))
Y_test_resh = Y_test_flatten.reshape((1, 75*OUTPUT_DIST_NUM))

# %%
plt.scatter(X_test_results_resh, Y_test_resh, c='r', s = 2)
plt.xlabel ('Training Data Prediction')
plt.ylabel ('Training Data Label')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Plot Loss

# %%
plt.plot(loss_list_epoch)
plt.show()

# %% [markdown]
# This is the loss plot for this model. I accidentally rerun the above cell and the output is erased, so I just put the result plot here.

# %% [markdown]
# ![](https://i.imgur.com/4rqHApM.png)

# %% [markdown]
# ## Plot RF distance

# %%
for index in range(15):
    index_RF_dist = [each[index] for each in RF_list_distance_epoch]
    plt.plot(index_RF_dist)
    plt.xlabel ('Epochs Index')
    plt.ylabel ('RFR Distance')
    plt.show()

# %%
plt.plot(RF_avg_distance_epoch)
plt.xlabel ('Epochs Index')
plt.ylabel ('RFR Distance')
plt.show()
